# %%
# import dependencis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# study data
temp_data = ("../temp.csv")
production_data = ("../production.csv")
# data are chosen as sample of countries
# crops are any crop produced that has value for every year along study time
# temperature is for all 12 months from 1961 to 2018, it can be filtered or groupedby to get average temp

# %%
#read csv files/production data
production_df = pd.read_csv(production_data)
production_df.head()
# Out:
#   Domain Code Domain  Area Code       Area  Element Code     Element  \
# 0          QC  Crops         10  Australia          5510  Production
# 1          QC  Crops         10  Australia          5510  Production
# 2          QC  Crops         10  Australia          5510  Production
# 3          QC  Crops         10  Australia          5510  Production
# 4          QC  Crops         10  Australia          5510  Production
#
#    Item Code    Item  Year Code  Year    Unit     Value Flag Flag Description
# 0        515  Apples       1961  1961  tonnes  295034.0  NaN    Official data
# 1        515  Apples       1962  1962  tonnes  326282.0  NaN    Official data
# 2        515  Apples       1963  1963  tonnes  349571.0  NaN    Official data
# 3        515  Apples       1964  1964  tonnes  367397.0  NaN    Official data
# 4        515  Apples       1965  1965  tonnes  360002.0  NaN    Official data

# %% [raw]
# # read csv files/ temp data

# %%
temp_df = pd.read_csv(temp_data)
temp_df.head()
# Out:
#   Domain Code              Domain  Area Code       Area  Element Code  \
# 0          ET  Temperature change         10  Australia          7271
# 1          ET  Temperature change         10  Australia          7271
# 2          ET  Temperature change         10  Australia          7271
# 3          ET  Temperature change         10  Australia          7271
# 4          ET  Temperature change         10  Australia          7271
#
#               Element  Months Code   Months  Year Code  Year Unit  Value Flag  \
# 0  Temperature change         7001  January       1961  1961  Â°C  0.202   Fc
# 1  Temperature change         7001  January       1962  1962  Â°C -0.087   Fc
# 2  Temperature change         7001  January       1963  1963  Â°C -0.709   Fc
# 3  Temperature change         7001  January       1964  1964  Â°C -0.242   Fc
# 4  Temperature change         7001  January       1965  1965  Â°C -0.181   Fc
#
#   Flag Description
# 0  Calculated data
# 1  Calculated data
# ...

# %%
# agricultutal production grouped by Area
grouped_df = production_df.groupby("Area").mean()
grouped_df
# Out:
#                           Area Code  Element Code   Item Code    Year Code  \
# Area
# Australia                      10.0        5510.0  236.500000  1989.500000
# Brazil                         21.0        5510.0  226.363636  1989.500000
# Canada                         33.0        5510.0  183.666667  1989.500000
# China                         351.0        5510.0  216.500000  1989.500000
# Egypt                          59.0        5510.0  236.509666  1989.954306
# Ghana                          81.0        5510.0  260.738255  1990.140940
# India                         100.0        5510.0  223.000000  1989.500000
# Israel                        105.0        5510.0  275.142857  1989.500000
# Mexico                        138.0        5510.0  216.500000  1989.500000
# Norway                        162.0        5510.0  172.500000  1989.500000
# United States of America      231.0        5510.0  230.582237  1990.190789
#
#                                  Year         Value
# Area
# ...

# %%
# get 
max_df = production_df["Area"].max()
# max will just give alph max
max_df
# Out:
# 'United States of America'

# %%
groupby_df = production_df.groupby(["Area", "Item", "Value"]).count()
groupby_df
#multi index
# Out:
#                                             Domain Code  Domain  Area Code  \
# Area                     Item   Value
# Australia                Apples 258360.0              1       1          1
#                                 264401.0              1       1          1
#                                 265481.0              1       1          1
#                                 266771.0              1       1          1
#                                 266998.0              1       1          1
# ...                                                 ...     ...        ...
# United States of America Wheat  69327000.0            1       1          1
#                                 70618000.0            1       1          1
#                                 74294000.0            1       1          1
#                                 75251296.0            1       1          1
#                                 75806304.0            1       1          1
#
# ...

# %%
# merge on year and drop any value that is null or nan 
#merged_df = production_df.merge(temp_df, on="Year", how="left")
#merged_df.head()
# need formula for dropna
#
#

# %%
maxpro_df = production_df.groupby(['Area','Item'])['Value'].max()
maxpro_df
# Out:
# Area                      Item
# Australia                 Apples            452650.0
#                           Bananas           412972.0
#                           Barley          13505990.0
#                           Beans, dry         65247.0
#                           Olives            122570.0
#                                             ...
# United States of America  Oranges         12401000.0
#                           Potatoes        23293964.0
#                           Rice, paddy     11027010.0
#                           Soybeans       123664230.0
#                           Wheat           75806304.0
# Name: Value, Length: 99, dtype: float64

# %%
# merge two dataframes together to use temperature change in the model
merged_df = pd.merge(production_df, temp_df, how="left", on="Year")

merged_df
# Out:
#         Domain Code_x Domain_x  Area Code_x                    Area_x  \
# 0                  QC    Crops           10                 Australia
# 1                  QC    Crops           10                 Australia
# 2                  QC    Crops           10                 Australia
# 3                  QC    Crops           10                 Australia
# 4                  QC    Crops           10                 Australia
# ...               ...      ...          ...                       ...
# 2113469            QC    Crops          231  United States of America
# 2113470            QC    Crops          231  United States of America
# 2113471            QC    Crops          231  United States of America
# 2113472            QC    Crops          231  United States of America
# 2113473            QC    Crops          231  United States of America
#
#          Element Code_x   Element_x  Item Code    Item  Year Code_x  Year  \
# ...
